# %% [markdown]
# ### Applied Data Science Capstone

# %% [markdown]
# ![note.jpg](attachment:note.jpg)

# %% [markdown]
# #### Notebook is related Coursera Capstone Project

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
